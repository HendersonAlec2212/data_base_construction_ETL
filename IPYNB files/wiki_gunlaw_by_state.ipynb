# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Gun_laws_in_the_United_States_by_state'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                                   0
#  0                        Firearm legal topics of the
#  1                                      United States
#  2  Amendment II Assault weapon Assault weapons le...
#  3                               United States portal
#  4  .mw-parser-output .navbar{display:inline;font-...,
#                                        Subject/Law Long Guns Hand Guns  \
#  0              State permit required to purchase?        No        No
#  1                           Firearm registration?        No        No
#  2                             Assault weapon law?        No        No
#  3                  Magazine capacity restriction?        No        No
#  4                         Owner license required?        No        No
#  5            Permit required for concealed carry?       NaN       Yes
#  6                 Permit required for open carry?        No        No
#  7          Castle Doctrine/Stand Your Ground law?       Yes       Yes
# ...

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 60

# %%
#50 states Plus+ DC, America Samoa, Guam, Northern Mariana Islands, Puerto Rico, US Virgin

# %%
tables[25]
# Out:
#                                       Subject/Law Long Guns Hand Guns  \
# 0              State permit required to purchase?        No        No
# 1                           Firearm registration?        No        No
# 2                             Assault weapon law?        No        No
# 3                  Magazine capacity restriction?        No        No
# 4                         Owner license required?        No        No
# 5            Permit required for concealed carry?       NaN        No
# 6                 Permit required for open carry?        No        No
# 7          Castle Doctrine/Stand Your Ground law?       Yes       Yes
# 8         State preemption of local restrictions?       Yes       Yes
# 9                         NFA weapons restricted?        No        No
# 10                        Peaceable Journey laws?        No        No
# 11  Background checks required for private sales?        No        No
#
#                                     Relevant Statutes  \
# ...

# %%
tables[58]
# Out:
#                  vteGun control in the United States  \
# 0  Assault weapons legislation Child access preve...
#
#                vteGun control in the United States.1
# 0  Assault weapons legislation Child access preve...

# %%
html_table = df.to_html()
html_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8e11c4076930> in <module>
# ----> 1 html_table = df.to_html()
#       2 html_table
#
# NameError: name 'df' is not defined
