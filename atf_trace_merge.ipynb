# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\Alec\\Documents\\Programming Resources\\Boot Camp\\13_project02\\project_02_ETL_LOCAL'

# %%
infile2014 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2014.xlsx'
infile2015 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2015.xlsx'
infile2016 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2016.xlsx'
infile2017 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2017.xlsx'
infile2018 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2018.xlsx'
infile2019 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2019.xlsx'
infile2020 = 'resources\\crime_related_firearms_traced\\sourcerecovery_by_state_cy2020.xlsx'

# %%
traced_firearm_2014_df = pd.read_excel(infile2014)
traced_firearm_2015_df = pd.read_excel(infile2015)
traced_firearm_2016_df = pd.read_excel(infile2016)
traced_firearm_2017_df = pd.read_excel(infile2017)
traced_firearm_2018_df = pd.read_excel(infile2018)
traced_firearm_2019_df = pd.read_excel(infile2019)
traced_firearm_2020_df = pd.read_excel(infile2020)

# %%
x = [0,55,56,57,58,59,60,61]

traced_firearm_2014_df = traced_firearm_2014_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2014_df = traced_firearm_2014_df.drop(x)
traced_firearm_2014_df = traced_firearm_2014_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})

# %%
traced_firearm_2015_df = traced_firearm_2015_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2015_df = traced_firearm_2015_df.drop(x)
traced_firearm_2015_df = traced_firearm_2015_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})

# %%
traced_firearm_2016_df = traced_firearm_2016_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2016_df = traced_firearm_2016_df.drop(x)
traced_firearm_2016_df = traced_firearm_2016_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})
traced_firearm_2016_df
# Out:
#                               state totals
# 1                           ALABAMA   5724
# 2                            ALASKA   1038
# 3                           ARIZONA   8203
# 4                          ARKANSAS   2477
# 5                        CALIFORNIA  18504
# 6                          COLORADO   3330
# 7                       CONNECTICUT    451
# 8                          DELAWARE    805
# 9              DISTRICT OF COLUMBIA     85
# 10                          FLORIDA  15645
# 11                          GEORGIA  12864
# 12  GUAM & NORTHERN MARIANA ISLANDS     23
# 13                           HAWAII    109
# 14                            IDAHO   1033
# 15                         ILLINOIS   5306
# 16                          INDIANA   7224
# 17                             IOWA   1466
# 18                           KANSAS   2266
# 19                         KENTUCKY   4276
# 20                        LOUISIANA   6645
# 21                            MAINE    495
# ...

# %%
traced_firearm_2017_df = traced_firearm_2017_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2017_df = traced_firearm_2017_df.drop(x)
traced_firearm_2017_df = traced_firearm_2017_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})
traced_firearm_2017_df
# Out:
#                    state totals
# 1                ALABAMA   6713
# 2                 ALASKA   1088
# 3                ARIZONA   7315
# 4               ARKANSAS   2016
# 5             CALIFORNIA  19392
# 6               COLORADO   3757
# 7            CONNECTICUT    751
# 8               DELAWARE    836
# 9   DISTRICT OF COLUMBIA     92
# 10               FLORIDA  17099
# 11               GEORGIA  14690
# 12                  GUAM     28
# 13                HAWAII     77
# 14                 IDAHO   1228
# 15              ILLINOIS   6171
# 16               INDIANA   8453
# 17                  IOWA   1812
# 18                KANSAS   2470
# 19              KENTUCKY   5455
# 20             LOUISIANA   8086
# 21                 MAINE    576
# 22              MARYLAND   3458
# 23         MASSACHUSETTS    709
# 24              MICHIGAN   4581
# 25             MINNESOTA   2488
# 26           MISSISSIPPI   4839
# 27              MISSOURI   5632
# 28               MONTANA    843
# ...

# %%
traced_firearm_2018_df = traced_firearm_2018_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2018_df = traced_firearm_2018_df.drop(x)
traced_firearm_2018_df = traced_firearm_2018_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})
traced_firearm_2018_df
# Out:
#                    state totals
# 1                ALABAMA   7051
# 2                 ALASKA   1004
# 3                ARIZONA   8674
# 4               ARKANSAS   2676
# 5             CALIFORNIA  18874
# 6               COLORADO   4128
# 7            CONNECTICUT    881
# 8               DELAWARE    862
# 9   DISTRICT OF COLUMBIA     82
# 10               FLORIDA  18702
# 11               GEORGIA  15350
# 12                  GUAM     22
# 13                HAWAII     92
# 14                 IDAHO   1280
# 15              ILLINOIS   6585
# 16               INDIANA   8721
# 17                  IOWA   1992
# 18                KANSAS   2951
# 19              KENTUCKY   5702
# 20             LOUISIANA   8025
# 21                 MAINE    586
# 22              MARYLAND   4194
# 23         MASSACHUSETTS    766
# 24              MICHIGAN   4544
# 25             MINNESOTA   2638
# 26           MISSISSIPPI   4930
# 27              MISSOURI   7437
# 28               MONTANA    991
# ...

# %%
traced_firearm_2019_df = traced_firearm_2019_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2019_df = traced_firearm_2019_df.drop(x)
traced_firearm_2019_df = traced_firearm_2019_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})
traced_firearm_2019_df
# Out:
#                               state totals
# 1                           ALABAMA   7873
# 2                            ALASKA   1127
# 3                           ARIZONA   9563
# 4                          ARKANSAS   3265
# 5                        CALIFORNIA  18486
# 6                          COLORADO   4331
# 7                       CONNECTICUT    696
# 8                          DELAWARE    969
# 9              DISTRICT OF COLUMBIA    115
# 10                          FLORIDA  19522
# 11                          GEORGIA  16428
# 12  GUAM & NORTHERN MARIANA ISLANDS     17
# 13                           HAWAII    121
# 14                            IDAHO   1363
# 15                         ILLINOIS   7144
# 16                          INDIANA   9480
# 17                             IOWA   2073
# 18                           KANSAS   2728
# 19                         KENTUCKY   6198
# 20                        LOUISIANA   8521
# 21                            MAINE    650
# ...

# %%
traced_firearm_2020_df = traced_firearm_2020_df[['Unnamed: 1', 'Unnamed: 56']].copy()
traced_firearm_2020_df = traced_firearm_2020_df.drop(x)
traced_firearm_2020_df = traced_firearm_2020_df.rename(columns={'Unnamed: 1':'state', 'Unnamed: 56':'totals'})
traced_firearm_2020_df
# Out:
#                               state totals
# 1                           ALABAMA   8199
# 2                            ALASKA    907
# 3                           ARIZONA  12361
# 4                          ARKANSAS   3516
# 5                        CALIFORNIA  17086
# 6                          COLORADO   4918
# 7                       CONNECTICUT    607
# 8                          DELAWARE   1203
# 9              DISTRICT OF COLUMBIA     91
# 10                          FLORIDA  22285
# 11                          GEORGIA  19120
# 12  GUAM & NORTHERN MARIANA ISLANDS     20
# 13                           HAWAII     66
# 14                            IDAHO   1417
# 15                         ILLINOIS   7116
# 16                          INDIANA   9684
# 17                             IOWA   2183
# 18                           KANSAS   3360
# 19                         KENTUCKY   6180
# 20                        LOUISIANA   9446
# 21                            MAINE    774
# ...

# %% [markdown]
# traced_firearm_2014_df.to_csv('resources\\crime_related_firearms_traced\\clean2014.csv')
# traced_firearm_2015_df.to_csv('resources\\crime_related_firearms_traced\\clean2015.csv')
# traced_firearm_2016_df.to_csv('resources\\crime_related_firearms_traced\\clean2016.csv')
# traced_firearm_2017_df.to_csv('resources\\crime_related_firearms_traced\\clean2017.csv')
# traced_firearm_2018_df.to_csv('resources\\crime_related_firearms_traced\\clean2018.csv')
# traced_firearm_2019_df.to_csv('resources\\crime_related_firearms_traced\\clean2019.csv')
# traced_firearm_2020_df.to_csv('resources\\crime_related_firearms_traced\\clean2020.csv')

# %%
df_14_15 = traced_firearm_2014_df.merge(traced_firearm_2015_df, how='inner',on=['state'],suffixes=('_2014','_2015'))
df_16_17 = traced_firearm_2016_df.merge(traced_firearm_2017_df, how='inner',on=['state'],suffixes=('_2016','_2017'))
df_18_19= traced_firearm_2018_df.merge(traced_firearm_2019_df, how='inner',on=['state'],suffixes=('_2018','_2019'))

# %%
master_clean = df_14_15.merge(df_16_17, how='inner', on=['state'])

# %%
master_clean = master_clean.merge(df_18_19, how='inner', on=['state'])

# %%
master_clean = master_clean.merge(traced_firearm_2020_df, how='inner', on=['state'])
# Out:
#                    state totals_2014 totals_2015 totals_2016 totals_2017  \
# 0                ALABAMA        5191        5254        5724        6713
# 1                 ALASKA         768         877        1038        1088
# 2                ARIZONA        6606        7785        8203        7315
# 3               ARKANSAS        1287        1564        2477        2016
# 4             CALIFORNIA       16999       18192       18504       19392
# 5               COLORADO        2524        2835        3330        3757
# 6            CONNECTICUT         799         558         451         751
# 7               DELAWARE         657         674         805         836
# 8   DISTRICT OF COLUMBIA          73          67          85          92
# 9                FLORIDA       14136       14305       15645       17099
# 10               GEORGIA        9989       10891       12864       14690
# 11                HAWAII          62          77         109          77
# ...

# %%
master_clean = master_clean.rename(columns={'totals':'totals_2020'})

# %%
master_clean.to_csv('resources\\crime_related_firearms_traced\\master_traced_firearms.csv')
